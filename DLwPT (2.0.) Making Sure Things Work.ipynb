# %% [markdown]
# # **Chapter 02: Pre-Trained Networks**

# %%
import torch

# %%
torch.version.__version__
# Out:
# '1.6.0+cu101'

# %%
a=torch.ones(3,3)

# %%
b=torch.ones(3,3)

# %%
a+b
# Out:
# tensor([[2., 2., 2.],
#         [2., 2., 2.],
#         [2., 2., 2.]])

# %%
a=a.to('cuda')
b=b.to('cuda')
a+b
